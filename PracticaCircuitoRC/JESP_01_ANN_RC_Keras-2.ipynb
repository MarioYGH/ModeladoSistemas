# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn import preprocessing
from keras.models import Sequential 
from keras.layers import Input, Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, explained_variance_score

# %%
# 1. Importar la base de datos del circuito RC
RC_circuit_db = pd.read_csv('db_completa_RC_Tecnologia.csv')
RC_circuit_db.head()
# Out:
#    time  voltaje_ent  voltaje_cap_5  Resistencia real  Capacitancia Real
# 0     0         4.93           0.00             53300                100
# 1   200         4.93           0.00             53300                100
# 2   400         4.93           0.02             53300                100
# 3   600         4.93           0.24             53300                100
# 4   800         4.93           0.43             53300                100

# %%
# 2. Normalizar mis datos

# %%
def normalize(x, xmin, xmax):
    return (xmax - xmin)*((x - np.min(x))/(np.max(x) - np.min(x))) + xmin

# %%
#X = [tiempo, R, C, Ve]
#y = [Vc]

R = normalize(RC_circuit_db['Resistencia real'], 0.1, 0.8)
C = normalize(RC_circuit_db['Capacitancia Real'], 0.1, 0.8)
t = normalize(RC_circuit_db['time'], 0.1, 0.8)
Ve = RC_circuit_db['voltaje_ent']

# Input variables
X = np.vstack([R, C, t, Ve]).T

# Target
y = RC_circuit_db['voltaje_cap_5']

# %%
# 3. Segmentar la base de datos
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 2002)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (14000, 4)
# (6000, 4)
# (14000,)
# (6000,)

# %%
# 4. Definimos la topologia de la ANN
from tensorflow.keras.layers import Dropout
from tensorflow.keras.optimizers import Adam


n_neurons = 16  # Aumentado el número de neuronas
model = Sequential(name="Improved-Model")
model.add(Input(shape=(X.shape[1],), name='Input-Layer'))
model.add(Dense(n_neurons, activation='relu', name='Hidden-Layer-1'))
model.add(Dropout(0.3))  # Dropout para regularización
model.add(Dense(n_neurons, activation='relu', name='Hidden-Layer-2'))
model.add(Dropout(0.3))
model.add(Dense(1, activation='linear', name='Output-Layer'))
model.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=['mae'])
model.summary()
# Out:
# Model: "Improved-Model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Hidden-Layer-1 (Dense)          │ (None, 16)             │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden-Layer-2 (Dense)          │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output-Layer (Dense)            │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 369 (1.44 KB)
#  Trainable params: 369 (1.44 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# 5. Compile keras model
model.compile(optimizer = 'sgd', # default='rmsprop', an algorithm to be used in backpropagation
              loss = 'mean_squared_error', # Loss function to be optimized. A string (name of loss function), or a tf.keras.losses.Loss instance.
              metrics = ['mean_squared_error','mean_absolute_error'], # List of metrics to be evaluated by the model during training and testing. Each of this can be a string (name of a built-in function), function or a tf.keras.metrics.Metric instance. 
            )

# %%
# 6. Entrenamos el modelo
history = model.fit(X_train, # input data
                    y_train, # target data
                    #batch_size = 10, # Number of samples per gradient update. If unspecified, batch_size will default to 32.
                    epochs = 500, # default=1, Number of epochs to train the model. An epoch is an iteration over the entire x and y data provided
                    verbose = 1, # default='auto', ('auto', 0, 1, or 2). Verbosity mode. 0 = silent, 1 = progress bar, 2 = one line per epoch. 'auto' defaults to 1 for most cases, but 2 when used with ParameterServerStrategy.
                    #callbacks = [earlyStopping, mcp_save],
                    validation_data = (X_test, y_test))
# Out:
# Epoch 1/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 3.6407 - mean_absolute_error: 1.5966 - mean_squared_error: 3.6407 - val_loss: 1.9379 - val_mean_absolute_error: 1.1804 - val_mean_squared_error: 1.9379
# Epoch 2/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.2159 - mean_absolute_error: 1.2431 - mean_squared_error: 2.2159 - val_loss: 1.1917 - val_mean_absolute_error: 0.8863 - val_mean_squared_error: 1.1917
# Epoch 3/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.4844 - mean_absolute_error: 0.9915 - mean_squared_error: 1.4844 - val_loss: 1.1190 - val_mean_absolute_error: 0.8667 - val_mean_squared_error: 1.1190
# Epoch 4/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.3098 - mean_absolute_error: 0.9214 - mean_squared_error: 1.3098 - val_loss: 1.0122 - val_mean_absolute_error: 0.8072 - val_mean_squared_error: 1.0122
# Epoch 5/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.2777 - mean_absolute_error: 0.9020 - mean_squared_error: 1.2777 - val_loss: 1.5883 - val_mean_absolute_error: 1.0718 - val_mean_squared_error: 1.5883
# Epoch 6/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.2078 - mean_absolute_error: 0.8777 - mean_squared_error: 1.2078 - val_loss: 1.0690 - val_mean_absolute_error: 0.8427 - val_mean_squared_error: 1.0690
# Epoch 7/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.2018 - mean_absolute_error: 0.8834 - mean_squared_error: 1.2018 - val_loss: 0.9999 - val_mean_absolute_error: 0.8071 - val_mean_squared_error: 0.9999
# Epoch 8/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.2265 - mean_absolute_error: 0.8830 - mean_squared_error: 1.2265 - val_loss: 1.4235 - val_mean_absolute_error: 1.0069 - val_mean_squared_error: 1.4235
# Epoch 9/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1857 - mean_absolute_error: 0.8704 - mean_squared_error: 1.1857 - val_loss: 1.0104 - val_mean_absolute_error: 0.8113 - val_mean_squared_error: 1.0104
# Epoch 10/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1426 - mean_absolute_error: 0.8550 - mean_squared_error: 1.1426 - val_loss: 1.0962 - val_mean_absolute_error: 0.8508 - val_mean_squared_error: 1.0962
# Epoch 11/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1675 - mean_absolute_error: 0.8702 - mean_squared_error: 1.1675 - val_loss: 1.3255 - val_mean_absolute_error: 0.9635 - val_mean_squared_error: 1.3255
# Epoch 12/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1830 - mean_absolute_error: 0.8671 - mean_squared_error: 1.1830 - val_loss: 1.1446 - val_mean_absolute_error: 0.8722 - val_mean_squared_error: 1.1446
# Epoch 13/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.2404 - mean_absolute_error: 0.8839 - mean_squared_error: 1.2404 - val_loss: 1.1875 - val_mean_absolute_error: 0.8951 - val_mean_squared_error: 1.1875
# Epoch 14/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.2023 - mean_absolute_error: 0.8770 - mean_squared_error: 1.2023 - val_loss: 1.0608 - val_mean_absolute_error: 0.8329 - val_mean_squared_error: 1.0608
# Epoch 15/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1892 - mean_absolute_error: 0.8735 - mean_squared_error: 1.1892 - val_loss: 1.0233 - val_mean_absolute_error: 0.8171 - val_mean_squared_error: 1.0233
# Epoch 16/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1178 - mean_absolute_error: 0.8490 - mean_squared_error: 1.1178 - val_loss: 1.2861 - val_mean_absolute_error: 0.9516 - val_mean_squared_error: 1.2861
# Epoch 17/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1643 - mean_absolute_error: 0.8569 - mean_squared_error: 1.1643 - val_loss: 1.0809 - val_mean_absolute_error: 0.8499 - val_mean_squared_error: 1.0809
# Epoch 18/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1775 - mean_absolute_error: 0.8642 - mean_squared_error: 1.1775 - val_loss: 2.0200 - val_mean_absolute_error: 1.2333 - val_mean_squared_error: 2.0200
# Epoch 19/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1677 - mean_absolute_error: 0.8627 - mean_squared_error: 1.1677 - val_loss: 1.2405 - val_mean_absolute_error: 0.9237 - val_mean_squared_error: 1.2405
# Epoch 20/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1267 - mean_absolute_error: 0.8461 - mean_squared_error: 1.1267 - val_loss: 1.2084 - val_mean_absolute_error: 0.9068 - val_mean_squared_error: 1.2084
# Epoch 21/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1235 - mean_absolute_error: 0.8508 - mean_squared_error: 1.1235 - val_loss: 1.0904 - val_mean_absolute_error: 0.8531 - val_mean_squared_error: 1.0904
# Epoch 22/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1614 - mean_absolute_error: 0.8585 - mean_squared_error: 1.1614 - val_loss: 1.1684 - val_mean_absolute_error: 0.8823 - val_mean_squared_error: 1.1684
# Epoch 23/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.1153 - mean_absolute_error: 0.8441 - mean_squared_error: 1.1153 - val_loss: 0.8719 - val_mean_absolute_error: 0.7345 - val_mean_squared_error: 0.8719
# Epoch 24/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1053 - mean_absolute_error: 0.8413 - mean_squared_error: 1.1053 - val_loss: 1.3020 - val_mean_absolute_error: 0.9473 - val_mean_squared_error: 1.3020
# Epoch 25/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1335 - mean_absolute_error: 0.8453 - mean_squared_error: 1.1335 - val_loss: 1.1438 - val_mean_absolute_error: 0.8792 - val_mean_squared_error: 1.1438
# Epoch 26/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1064 - mean_absolute_error: 0.8390 - mean_squared_error: 1.1064 - val_loss: 1.2585 - val_mean_absolute_error: 0.9238 - val_mean_squared_error: 1.2585
# Epoch 27/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1233 - mean_absolute_error: 0.8399 - mean_squared_error: 1.1233 - val_loss: 1.0460 - val_mean_absolute_error: 0.8311 - val_mean_squared_error: 1.0460
# Epoch 28/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1068 - mean_absolute_error: 0.8424 - mean_squared_error: 1.1068 - val_loss: 1.1442 - val_mean_absolute_error: 0.8648 - val_mean_squared_error: 1.1442
# Epoch 29/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1431 - mean_absolute_error: 0.8462 - mean_squared_error: 1.1431 - val_loss: 1.2520 - val_mean_absolute_error: 0.9213 - val_mean_squared_error: 1.2520
# Epoch 30/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1422 - mean_absolute_error: 0.8420 - mean_squared_error: 1.1422 - val_loss: 1.3643 - val_mean_absolute_error: 0.9804 - val_mean_squared_error: 1.3643
# Epoch 31/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1030 - mean_absolute_error: 0.8410 - mean_squared_error: 1.1030 - val_loss: 1.1144 - val_mean_absolute_error: 0.8515 - val_mean_squared_error: 1.1144
# Epoch 32/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0784 - mean_absolute_error: 0.8245 - mean_squared_error: 1.0784 - val_loss: 1.0357 - val_mean_absolute_error: 0.8321 - val_mean_squared_error: 1.0357
# Epoch 33/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0962 - mean_absolute_error: 0.8304 - mean_squared_error: 1.0962 - val_loss: 0.9782 - val_mean_absolute_error: 0.7925 - val_mean_squared_error: 0.9782
# Epoch 34/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1214 - mean_absolute_error: 0.8323 - mean_squared_error: 1.1214 - val_loss: 1.0231 - val_mean_absolute_error: 0.8118 - val_mean_squared_error: 1.0231
# Epoch 35/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1108 - mean_absolute_error: 0.8400 - mean_squared_error: 1.1108 - val_loss: 1.2570 - val_mean_absolute_error: 0.9299 - val_mean_squared_error: 1.2570
# Epoch 36/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1188 - mean_absolute_error: 0.8406 - mean_squared_error: 1.1188 - val_loss: 0.9388 - val_mean_absolute_error: 0.7619 - val_mean_squared_error: 0.9388
# Epoch 37/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1127 - mean_absolute_error: 0.8275 - mean_squared_error: 1.1127 - val_loss: 1.0487 - val_mean_absolute_error: 0.8151 - val_mean_squared_error: 1.0487
# Epoch 38/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1120 - mean_absolute_error: 0.8373 - mean_squared_error: 1.1120 - val_loss: 1.0756 - val_mean_absolute_error: 0.8327 - val_mean_squared_error: 1.0756
# Epoch 39/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1217 - mean_absolute_error: 0.8383 - mean_squared_error: 1.1217 - val_loss: 1.1533 - val_mean_absolute_error: 0.8666 - val_mean_squared_error: 1.1533
# Epoch 40/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0737 - mean_absolute_error: 0.8207 - mean_squared_error: 1.0737 - val_loss: 0.9084 - val_mean_absolute_error: 0.7406 - val_mean_squared_error: 0.9084
# Epoch 41/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0983 - mean_absolute_error: 0.8287 - mean_squared_error: 1.0983 - val_loss: 1.3246 - val_mean_absolute_error: 0.9600 - val_mean_squared_error: 1.3246
# Epoch 42/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0947 - mean_absolute_error: 0.8264 - mean_squared_error: 1.0947 - val_loss: 1.0766 - val_mean_absolute_error: 0.8345 - val_mean_squared_error: 1.0766
# Epoch 43/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.0917 - mean_absolute_error: 0.8256 - mean_squared_error: 1.0917 - val_loss: 1.2625 - val_mean_absolute_error: 0.9311 - val_mean_squared_error: 1.2625
# Epoch 44/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0787 - mean_absolute_error: 0.8209 - mean_squared_error: 1.0787 - val_loss: 1.1067 - val_mean_absolute_error: 0.8509 - val_mean_squared_error: 1.1067
# Epoch 45/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1388 - mean_absolute_error: 0.8367 - mean_squared_error: 1.1388 - val_loss: 1.2035 - val_mean_absolute_error: 0.9012 - val_mean_squared_error: 1.2035
# Epoch 46/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.1127 - mean_absolute_error: 0.8333 - mean_squared_error: 1.1127 - val_loss: 1.1168 - val_mean_absolute_error: 0.8534 - val_mean_squared_error: 1.1168
# Epoch 47/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.1151 - mean_absolute_error: 0.8382 - mean_squared_error: 1.1151 - val_loss: 1.0047 - val_mean_absolute_error: 0.8005 - val_mean_squared_error: 1.0047
# Epoch 48/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1.0815 - mean_absolute_error: 0.8204 - mean_squared_error: 1.0815 - val_loss: 1.3586 - val_mean_absolute_error: 0.9737 - val_mean_squared_error: 1.3586
# Epoch 49/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0645 - mean_absolute_error: 0.8239 - mean_squared_error: 1.0645 - val_loss: 1.2733 - val_mean_absolute_error: 0.9313 - val_mean_squared_error: 1.2733
# Epoch 50/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0870 - mean_absolute_error: 0.8252 - mean_squared_error: 1.0870 - val_loss: 0.8560 - val_mean_absolute_error: 0.7093 - val_mean_squared_error: 0.8560
# Epoch 51/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0681 - mean_absolute_error: 0.8198 - mean_squared_error: 1.0681 - val_loss: 1.2205 - val_mean_absolute_error: 0.9112 - val_mean_squared_error: 1.2205
# Epoch 52/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.0785 - mean_absolute_error: 0.8157 - mean_squared_error: 1.0785 - val_loss: 1.1177 - val_mean_absolute_error: 0.8559 - val_mean_squared_error: 1.1177
# Epoch 53/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0963 - mean_absolute_error: 0.8249 - mean_squared_error: 1.0963 - val_loss: 1.1416 - val_mean_absolute_error: 0.8726 - val_mean_squared_error: 1.1416
# Epoch 54/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0910 - mean_absolute_error: 0.8235 - mean_squared_error: 1.0910 - val_loss: 1.1245 - val_mean_absolute_error: 0.8612 - val_mean_squared_error: 1.1245
# Epoch 55/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0620 - mean_absolute_error: 0.8211 - mean_squared_error: 1.0620 - val_loss: 1.4205 - val_mean_absolute_error: 1.0023 - val_mean_squared_error: 1.4205
# Epoch 56/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1164 - mean_absolute_error: 0.8356 - mean_squared_error: 1.1164 - val_loss: 1.1115 - val_mean_absolute_error: 0.8516 - val_mean_squared_error: 1.1115
# Epoch 57/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0788 - mean_absolute_error: 0.8260 - mean_squared_error: 1.0788 - val_loss: 1.0623 - val_mean_absolute_error: 0.8291 - val_mean_squared_error: 1.0623
# Epoch 58/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0841 - mean_absolute_error: 0.8254 - mean_squared_error: 1.0841 - val_loss: 1.0788 - val_mean_absolute_error: 0.8343 - val_mean_squared_error: 1.0788
# Epoch 59/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1048 - mean_absolute_error: 0.8246 - mean_squared_error: 1.1048 - val_loss: 1.0796 - val_mean_absolute_error: 0.8418 - val_mean_squared_error: 1.0796
# Epoch 60/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1044 - mean_absolute_error: 0.8263 - mean_squared_error: 1.1044 - val_loss: 1.1086 - val_mean_absolute_error: 0.8590 - val_mean_squared_error: 1.1086
# Epoch 61/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.1073 - mean_absolute_error: 0.8249 - mean_squared_error: 1.1073 - val_loss: 1.2125 - val_mean_absolute_error: 0.8992 - val_mean_squared_error: 1.2125
# Epoch 62/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0880 - mean_absolute_error: 0.8230 - mean_squared_error: 1.0880 - val_loss: 1.1101 - val_mean_absolute_error: 0.8443 - val_mean_squared_error: 1.1101
# Epoch 63/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0939 - mean_absolute_error: 0.8257 - mean_squared_error: 1.0939 - val_loss: 1.0764 - val_mean_absolute_error: 0.8365 - val_mean_squared_error: 1.0764
# Epoch 64/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0775 - mean_absolute_error: 0.8242 - mean_squared_error: 1.0775 - val_loss: 1.2570 - val_mean_absolute_error: 0.9255 - val_mean_squared_error: 1.2570
# Epoch 65/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0751 - mean_absolute_error: 0.8174 - mean_squared_error: 1.0751 - val_loss: 1.1764 - val_mean_absolute_error: 0.8867 - val_mean_squared_error: 1.1764
# Epoch 66/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0986 - mean_absolute_error: 0.8277 - mean_squared_error: 1.0986 - val_loss: 1.1367 - val_mean_absolute_error: 0.8636 - val_mean_squared_error: 1.1367
# Epoch 67/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1154 - mean_absolute_error: 0.8340 - mean_squared_error: 1.1154 - val_loss: 1.2817 - val_mean_absolute_error: 0.9375 - val_mean_squared_error: 1.2817
# Epoch 68/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0910 - mean_absolute_error: 0.8250 - mean_squared_error: 1.0910 - val_loss: 1.2119 - val_mean_absolute_error: 0.8990 - val_mean_squared_error: 1.2119
# Epoch 69/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0658 - mean_absolute_error: 0.8140 - mean_squared_error: 1.0658 - val_loss: 1.1478 - val_mean_absolute_error: 0.8659 - val_mean_squared_error: 1.1478
# Epoch 70/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0476 - mean_absolute_error: 0.8091 - mean_squared_error: 1.0476 - val_loss: 0.9135 - val_mean_absolute_error: 0.7459 - val_mean_squared_error: 0.9135
# Epoch 71/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0434 - mean_absolute_error: 0.8107 - mean_squared_error: 1.0434 - val_loss: 1.0452 - val_mean_absolute_error: 0.8188 - val_mean_squared_error: 1.0452
# Epoch 72/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0697 - mean_absolute_error: 0.8171 - mean_squared_error: 1.0697 - val_loss: 1.0027 - val_mean_absolute_error: 0.7950 - val_mean_squared_error: 1.0027
# Epoch 73/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0749 - mean_absolute_error: 0.8248 - mean_squared_error: 1.0749 - val_loss: 0.9334 - val_mean_absolute_error: 0.7506 - val_mean_squared_error: 0.9334
# Epoch 74/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0751 - mean_absolute_error: 0.8211 - mean_squared_error: 1.0751 - val_loss: 1.0599 - val_mean_absolute_error: 0.8194 - val_mean_squared_error: 1.0599
# Epoch 75/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1038 - mean_absolute_error: 0.8280 - mean_squared_error: 1.1038 - val_loss: 1.3261 - val_mean_absolute_error: 0.9573 - val_mean_squared_error: 1.3261
# Epoch 76/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0840 - mean_absolute_error: 0.8194 - mean_squared_error: 1.0840 - val_loss: 1.0954 - val_mean_absolute_error: 0.8495 - val_mean_squared_error: 1.0954
# Epoch 77/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0961 - mean_absolute_error: 0.8319 - mean_squared_error: 1.0961 - val_loss: 1.2128 - val_mean_absolute_error: 0.9064 - val_mean_squared_error: 1.2128
# Epoch 78/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0713 - mean_absolute_error: 0.8182 - mean_squared_error: 1.0713 - val_loss: 1.2411 - val_mean_absolute_error: 0.9211 - val_mean_squared_error: 1.2411
# Epoch 79/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0912 - mean_absolute_error: 0.8287 - mean_squared_error: 1.0912 - val_loss: 1.2429 - val_mean_absolute_error: 0.9215 - val_mean_squared_error: 1.2429
# Epoch 80/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1160 - mean_absolute_error: 0.8340 - mean_squared_error: 1.1160 - val_loss: 1.0562 - val_mean_absolute_error: 0.8302 - val_mean_squared_error: 1.0562
# Epoch 81/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0778 - mean_absolute_error: 0.8251 - mean_squared_error: 1.0778 - val_loss: 0.9839 - val_mean_absolute_error: 0.7874 - val_mean_squared_error: 0.9839
# Epoch 82/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0798 - mean_absolute_error: 0.8261 - mean_squared_error: 1.0798 - val_loss: 1.2107 - val_mean_absolute_error: 0.9062 - val_mean_squared_error: 1.2107
# Epoch 83/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0854 - mean_absolute_error: 0.8229 - mean_squared_error: 1.0854 - val_loss: 1.1097 - val_mean_absolute_error: 0.8535 - val_mean_squared_error: 1.1097
# Epoch 84/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0681 - mean_absolute_error: 0.8153 - mean_squared_error: 1.0681 - val_loss: 1.0263 - val_mean_absolute_error: 0.8104 - val_mean_squared_error: 1.0263
# Epoch 85/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1033 - mean_absolute_error: 0.8335 - mean_squared_error: 1.1033 - val_loss: 0.8251 - val_mean_absolute_error: 0.6896 - val_mean_squared_error: 0.8251
# Epoch 86/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0966 - mean_absolute_error: 0.8257 - mean_squared_error: 1.0966 - val_loss: 1.2608 - val_mean_absolute_error: 0.9269 - val_mean_squared_error: 1.2608
# Epoch 87/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1134 - mean_absolute_error: 0.8332 - mean_squared_error: 1.1134 - val_loss: 1.1745 - val_mean_absolute_error: 0.8878 - val_mean_squared_error: 1.1745
# Epoch 88/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0950 - mean_absolute_error: 0.8266 - mean_squared_error: 1.0950 - val_loss: 1.2793 - val_mean_absolute_error: 0.9396 - val_mean_squared_error: 1.2793
# Epoch 89/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0930 - mean_absolute_error: 0.8246 - mean_squared_error: 1.0930 - val_loss: 0.9729 - val_mean_absolute_error: 0.7774 - val_mean_squared_error: 0.9729
# Epoch 90/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0744 - mean_absolute_error: 0.8219 - mean_squared_error: 1.0744 - val_loss: 1.4292 - val_mean_absolute_error: 1.0066 - val_mean_squared_error: 1.4292
# Epoch 91/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0722 - mean_absolute_error: 0.8185 - mean_squared_error: 1.0722 - val_loss: 1.3717 - val_mean_absolute_error: 0.9763 - val_mean_squared_error: 1.3717
# Epoch 92/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1108 - mean_absolute_error: 0.8325 - mean_squared_error: 1.1108 - val_loss: 1.1129 - val_mean_absolute_error: 0.8474 - val_mean_squared_error: 1.1129
# Epoch 93/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0916 - mean_absolute_error: 0.8265 - mean_squared_error: 1.0916 - val_loss: 0.9619 - val_mean_absolute_error: 0.7795 - val_mean_squared_error: 0.9619
# Epoch 94/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0947 - mean_absolute_error: 0.8223 - mean_squared_error: 1.0947 - val_loss: 1.2119 - val_mean_absolute_error: 0.9053 - val_mean_squared_error: 1.2119
# Epoch 95/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0574 - mean_absolute_error: 0.8171 - mean_squared_error: 1.0574 - val_loss: 1.2526 - val_mean_absolute_error: 0.9299 - val_mean_squared_error: 1.2526
# Epoch 96/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0641 - mean_absolute_error: 0.8108 - mean_squared_error: 1.0641 - val_loss: 1.3239 - val_mean_absolute_error: 0.9542 - val_mean_squared_error: 1.3239
# Epoch 97/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0699 - mean_absolute_error: 0.8131 - mean_squared_error: 1.0699 - val_loss: 1.1872 - val_mean_absolute_error: 0.8917 - val_mean_squared_error: 1.1872
# Epoch 98/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0872 - mean_absolute_error: 0.8171 - mean_squared_error: 1.0872 - val_loss: 0.9959 - val_mean_absolute_error: 0.7958 - val_mean_squared_error: 0.9959
# Epoch 99/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.1006 - mean_absolute_error: 0.8287 - mean_squared_error: 1.1006 - val_loss: 0.9527 - val_mean_absolute_error: 0.7679 - val_mean_squared_error: 0.9527
# Epoch 100/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1375 - mean_absolute_error: 0.8445 - mean_squared_error: 1.1375 - val_loss: 0.9215 - val_mean_absolute_error: 0.7424 - val_mean_squared_error: 0.9215
# Epoch 101/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0962 - mean_absolute_error: 0.8240 - mean_squared_error: 1.0962 - val_loss: 1.0616 - val_mean_absolute_error: 0.8261 - val_mean_squared_error: 1.0616
# Epoch 102/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0458 - mean_absolute_error: 0.8017 - mean_squared_error: 1.0458 - val_loss: 1.1743 - val_mean_absolute_error: 0.8895 - val_mean_squared_error: 1.1743
# Epoch 103/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.0514 - mean_absolute_error: 0.8095 - mean_squared_error: 1.0514 - val_loss: 1.0278 - val_mean_absolute_error: 0.8114 - val_mean_squared_error: 1.0278
# Epoch 104/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0696 - mean_absolute_error: 0.8147 - mean_squared_error: 1.0696 - val_loss: 1.1715 - val_mean_absolute_error: 0.8874 - val_mean_squared_error: 1.1715
# Epoch 105/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0958 - mean_absolute_error: 0.8384 - mean_squared_error: 1.0958 - val_loss: 1.0216 - val_mean_absolute_error: 0.7926 - val_mean_squared_error: 1.0216
# Epoch 106/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0748 - mean_absolute_error: 0.8166 - mean_squared_error: 1.0748 - val_loss: 0.8845 - val_mean_absolute_error: 0.7226 - val_mean_squared_error: 0.8845
# Epoch 107/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.0552 - mean_absolute_error: 0.8125 - mean_squared_error: 1.0552 - val_loss: 1.1386 - val_mean_absolute_error: 0.8640 - val_mean_squared_error: 1.1386
# Epoch 108/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1.1132 - mean_absolute_error: 0.8278 - mean_squared_error: 1.1132 - val_loss: 1.5282 - val_mean_absolute_error: 1.0500 - val_mean_squared_error: 1.5282
# Epoch 109/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0782 - mean_absolute_error: 0.8199 - mean_squared_error: 1.0782 - val_loss: 0.9521 - val_mean_absolute_error: 0.7669 - val_mean_squared_error: 0.9521
# Epoch 110/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0777 - mean_absolute_error: 0.8215 - mean_squared_error: 1.0777 - val_loss: 1.2476 - val_mean_absolute_error: 0.9195 - val_mean_squared_error: 1.2476
# Epoch 111/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0811 - mean_absolute_error: 0.8204 - mean_squared_error: 1.0811 - val_loss: 1.0657 - val_mean_absolute_error: 0.8283 - val_mean_squared_error: 1.0657
# Epoch 112/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0752 - mean_absolute_error: 0.8198 - mean_squared_error: 1.0752 - val_loss: 0.9560 - val_mean_absolute_error: 0.7722 - val_mean_squared_error: 0.9560
# Epoch 113/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0799 - mean_absolute_error: 0.8219 - mean_squared_error: 1.0799 - val_loss: 1.1463 - val_mean_absolute_error: 0.8702 - val_mean_squared_error: 1.1463
# Epoch 114/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0875 - mean_absolute_error: 0.8166 - mean_squared_error: 1.0875 - val_loss: 1.2979 - val_mean_absolute_error: 0.9518 - val_mean_squared_error: 1.2979
# Epoch 115/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0898 - mean_absolute_error: 0.8282 - mean_squared_error: 1.0898 - val_loss: 1.2737 - val_mean_absolute_error: 0.9357 - val_mean_squared_error: 1.2737
# Epoch 116/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1162 - mean_absolute_error: 0.8336 - mean_squared_error: 1.1162 - val_loss: 1.3658 - val_mean_absolute_error: 0.9765 - val_mean_squared_error: 1.3658
# Epoch 117/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0934 - mean_absolute_error: 0.8188 - mean_squared_error: 1.0934 - val_loss: 1.1415 - val_mean_absolute_error: 0.8691 - val_mean_squared_error: 1.1415
# Epoch 118/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0905 - mean_absolute_error: 0.8225 - mean_squared_error: 1.0905 - val_loss: 0.9884 - val_mean_absolute_error: 0.7886 - val_mean_squared_error: 0.9884
# Epoch 119/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0621 - mean_absolute_error: 0.8155 - mean_squared_error: 1.0621 - val_loss: 1.1260 - val_mean_absolute_error: 0.8625 - val_mean_squared_error: 1.1260
# Epoch 120/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0729 - mean_absolute_error: 0.8150 - mean_squared_error: 1.0729 - val_loss: 1.1570 - val_mean_absolute_error: 0.8700 - val_mean_squared_error: 1.1570
# Epoch 121/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0737 - mean_absolute_error: 0.8160 - mean_squared_error: 1.0737 - val_loss: 1.1922 - val_mean_absolute_error: 0.9012 - val_mean_squared_error: 1.1922
# Epoch 122/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0821 - mean_absolute_error: 0.8164 - mean_squared_error: 1.0821 - val_loss: 1.1267 - val_mean_absolute_error: 0.8604 - val_mean_squared_error: 1.1267
# Epoch 123/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0636 - mean_absolute_error: 0.8170 - mean_squared_error: 1.0636 - val_loss: 1.1506 - val_mean_absolute_error: 0.8819 - val_mean_squared_error: 1.1506
# Epoch 124/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0563 - mean_absolute_error: 0.8155 - mean_squared_error: 1.0563 - val_loss: 1.2975 - val_mean_absolute_error: 0.9515 - val_mean_squared_error: 1.2975
# Epoch 125/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.0987 - mean_absolute_error: 0.8279 - mean_squared_error: 1.0987 - val_loss: 1.2221 - val_mean_absolute_error: 0.9111 - val_mean_squared_error: 1.2221
# Epoch 126/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.0958 - mean_absolute_error: 0.8294 - mean_squared_error: 1.0958 - val_loss: 0.9738 - val_mean_absolute_error: 0.7769 - val_mean_squared_error: 0.9738
# Epoch 127/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0692 - mean_absolute_error: 0.8198 - mean_squared_error: 1.0692 - val_loss: 1.3075 - val_mean_absolute_error: 0.9503 - val_mean_squared_error: 1.3075
# Epoch 128/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0661 - mean_absolute_error: 0.8146 - mean_squared_error: 1.0661 - val_loss: 1.3299 - val_mean_absolute_error: 0.9585 - val_mean_squared_error: 1.3299
# Epoch 129/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0804 - mean_absolute_error: 0.8169 - mean_squared_error: 1.0804 - val_loss: 1.2062 - val_mean_absolute_error: 0.8933 - val_mean_squared_error: 1.2062
# Epoch 130/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0787 - mean_absolute_error: 0.8249 - mean_squared_error: 1.0787 - val_loss: 1.1752 - val_mean_absolute_error: 0.8825 - val_mean_squared_error: 1.1752
# Epoch 131/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0702 - mean_absolute_error: 0.8221 - mean_squared_error: 1.0702 - val_loss: 1.2492 - val_mean_absolute_error: 0.9206 - val_mean_squared_error: 1.2492
# Epoch 132/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0951 - mean_absolute_error: 0.8168 - mean_squared_error: 1.0951 - val_loss: 1.1128 - val_mean_absolute_error: 0.8509 - val_mean_squared_error: 1.1128
# Epoch 133/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0637 - mean_absolute_error: 0.8171 - mean_squared_error: 1.0637 - val_loss: 1.1288 - val_mean_absolute_error: 0.8646 - val_mean_squared_error: 1.1288
# Epoch 134/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0453 - mean_absolute_error: 0.8096 - mean_squared_error: 1.0453 - val_loss: 1.0142 - val_mean_absolute_error: 0.7997 - val_mean_squared_error: 1.0142
# Epoch 135/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0728 - mean_absolute_error: 0.8216 - mean_squared_error: 1.0728 - val_loss: 1.0345 - val_mean_absolute_error: 0.8165 - val_mean_squared_error: 1.0345
# Epoch 136/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0462 - mean_absolute_error: 0.8107 - mean_squared_error: 1.0462 - val_loss: 1.1700 - val_mean_absolute_error: 0.8799 - val_mean_squared_error: 1.1700
# Epoch 137/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1024 - mean_absolute_error: 0.8227 - mean_squared_error: 1.1024 - val_loss: 0.9871 - val_mean_absolute_error: 0.7867 - val_mean_squared_error: 0.9871
# Epoch 138/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0588 - mean_absolute_error: 0.8114 - mean_squared_error: 1.0588 - val_loss: 1.1011 - val_mean_absolute_error: 0.8423 - val_mean_squared_error: 1.1011
# Epoch 139/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0920 - mean_absolute_error: 0.8243 - mean_squared_error: 1.0920 - val_loss: 1.1802 - val_mean_absolute_error: 0.8850 - val_mean_squared_error: 1.1802
# Epoch 140/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0866 - mean_absolute_error: 0.8164 - mean_squared_error: 1.0866 - val_loss: 0.9990 - val_mean_absolute_error: 0.7913 - val_mean_squared_error: 0.9990
# Epoch 141/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0866 - mean_absolute_error: 0.8221 - mean_squared_error: 1.0866 - val_loss: 1.0630 - val_mean_absolute_error: 0.8294 - val_mean_squared_error: 1.0630
# Epoch 142/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0885 - mean_absolute_error: 0.8180 - mean_squared_error: 1.0885 - val_loss: 1.2949 - val_mean_absolute_error: 0.9468 - val_mean_squared_error: 1.2949
# Epoch 143/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0769 - mean_absolute_error: 0.8263 - mean_squared_error: 1.0769 - val_loss: 1.0923 - val_mean_absolute_error: 0.8469 - val_mean_squared_error: 1.0923
# Epoch 144/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0969 - mean_absolute_error: 0.8195 - mean_squared_error: 1.0969 - val_loss: 1.1005 - val_mean_absolute_error: 0.8472 - val_mean_squared_error: 1.1005
# Epoch 145/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0987 - mean_absolute_error: 0.8229 - mean_squared_error: 1.0987 - val_loss: 1.1836 - val_mean_absolute_error: 0.8876 - val_mean_squared_error: 1.1836
# Epoch 146/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0857 - mean_absolute_error: 0.8230 - mean_squared_error: 1.0857 - val_loss: 1.0961 - val_mean_absolute_error: 0.8450 - val_mean_squared_error: 1.0961
# Epoch 147/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0604 - mean_absolute_error: 0.8141 - mean_squared_error: 1.0604 - val_loss: 1.1433 - val_mean_absolute_error: 0.8676 - val_mean_squared_error: 1.1433
# Epoch 148/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0976 - mean_absolute_error: 0.8229 - mean_squared_error: 1.0976 - val_loss: 1.1750 - val_mean_absolute_error: 0.8870 - val_mean_squared_error: 1.1750
# Epoch 149/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0463 - mean_absolute_error: 0.8080 - mean_squared_error: 1.0463 - val_loss: 1.1885 - val_mean_absolute_error: 0.8948 - val_mean_squared_error: 1.1885
# Epoch 150/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0914 - mean_absolute_error: 0.8169 - mean_squared_error: 1.0914 - val_loss: 1.0344 - val_mean_absolute_error: 0.8163 - val_mean_squared_error: 1.0344
# Epoch 151/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0687 - mean_absolute_error: 0.8173 - mean_squared_error: 1.0687 - val_loss: 1.2207 - val_mean_absolute_error: 0.9023 - val_mean_squared_error: 1.2207
# Epoch 152/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0804 - mean_absolute_error: 0.8125 - mean_squared_error: 1.0804 - val_loss: 1.1298 - val_mean_absolute_error: 0.8691 - val_mean_squared_error: 1.1298
# Epoch 153/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0781 - mean_absolute_error: 0.8231 - mean_squared_error: 1.0781 - val_loss: 1.2301 - val_mean_absolute_error: 0.9167 - val_mean_squared_error: 1.2301
# Epoch 154/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0744 - mean_absolute_error: 0.8117 - mean_squared_error: 1.0744 - val_loss: 1.2196 - val_mean_absolute_error: 0.9112 - val_mean_squared_error: 1.2196
# Epoch 155/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0573 - mean_absolute_error: 0.8170 - mean_squared_error: 1.0573 - val_loss: 1.0267 - val_mean_absolute_error: 0.8045 - val_mean_squared_error: 1.0267
# Epoch 156/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0964 - mean_absolute_error: 0.8247 - mean_squared_error: 1.0964 - val_loss: 1.0499 - val_mean_absolute_error: 0.8199 - val_mean_squared_error: 1.0499
# Epoch 157/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0883 - mean_absolute_error: 0.8258 - mean_squared_error: 1.0883 - val_loss: 0.9961 - val_mean_absolute_error: 0.7945 - val_mean_squared_error: 0.9961
# Epoch 158/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0663 - mean_absolute_error: 0.8164 - mean_squared_error: 1.0663 - val_loss: 1.1830 - val_mean_absolute_error: 0.8939 - val_mean_squared_error: 1.1830
# Epoch 159/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0576 - mean_absolute_error: 0.8118 - mean_squared_error: 1.0576 - val_loss: 1.1255 - val_mean_absolute_error: 0.8584 - val_mean_squared_error: 1.1255
# Epoch 160/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0651 - mean_absolute_error: 0.8127 - mean_squared_error: 1.0651 - val_loss: 1.1648 - val_mean_absolute_error: 0.8798 - val_mean_squared_error: 1.1648
# Epoch 161/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0941 - mean_absolute_error: 0.8222 - mean_squared_error: 1.0941 - val_loss: 1.2118 - val_mean_absolute_error: 0.9052 - val_mean_squared_error: 1.2118
# Epoch 162/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0923 - mean_absolute_error: 0.8218 - mean_squared_error: 1.0923 - val_loss: 1.1500 - val_mean_absolute_error: 0.8694 - val_mean_squared_error: 1.1500
# Epoch 163/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0880 - mean_absolute_error: 0.8216 - mean_squared_error: 1.0880 - val_loss: 1.2011 - val_mean_absolute_error: 0.8924 - val_mean_squared_error: 1.2011
# Epoch 164/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0590 - mean_absolute_error: 0.8139 - mean_squared_error: 1.0590 - val_loss: 1.0205 - val_mean_absolute_error: 0.8064 - val_mean_squared_error: 1.0205
# Epoch 165/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0870 - mean_absolute_error: 0.8198 - mean_squared_error: 1.0870 - val_loss: 1.0791 - val_mean_absolute_error: 0.8354 - val_mean_squared_error: 1.0791
# Epoch 166/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0687 - mean_absolute_error: 0.8136 - mean_squared_error: 1.0687 - val_loss: 1.0340 - val_mean_absolute_error: 0.8152 - val_mean_squared_error: 1.0340
# Epoch 167/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0714 - mean_absolute_error: 0.8161 - mean_squared_error: 1.0714 - val_loss: 1.1475 - val_mean_absolute_error: 0.8665 - val_mean_squared_error: 1.1475
# Epoch 168/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0233 - mean_absolute_error: 0.7986 - mean_squared_error: 1.0233 - val_loss: 1.0326 - val_mean_absolute_error: 0.8166 - val_mean_squared_error: 1.0326
# Epoch 169/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0770 - mean_absolute_error: 0.8143 - mean_squared_error: 1.0770 - val_loss: 0.9825 - val_mean_absolute_error: 0.7961 - val_mean_squared_error: 0.9825
# Epoch 170/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0604 - mean_absolute_error: 0.8125 - mean_squared_error: 1.0604 - val_loss: 1.3372 - val_mean_absolute_error: 0.9575 - val_mean_squared_error: 1.3372
# Epoch 171/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0805 - mean_absolute_error: 0.8164 - mean_squared_error: 1.0805 - val_loss: 1.1541 - val_mean_absolute_error: 0.8742 - val_mean_squared_error: 1.1541
# Epoch 172/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0312 - mean_absolute_error: 0.8039 - mean_squared_error: 1.0312 - val_loss: 1.1446 - val_mean_absolute_error: 0.8727 - val_mean_squared_error: 1.1446
# Epoch 173/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0668 - mean_absolute_error: 0.8145 - mean_squared_error: 1.0668 - val_loss: 1.1082 - val_mean_absolute_error: 0.8545 - val_mean_squared_error: 1.1082
# Epoch 174/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0847 - mean_absolute_error: 0.8221 - mean_squared_error: 1.0847 - val_loss: 1.1432 - val_mean_absolute_error: 0.8701 - val_mean_squared_error: 1.1432
# Epoch 175/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0702 - mean_absolute_error: 0.8170 - mean_squared_error: 1.0702 - val_loss: 1.0294 - val_mean_absolute_error: 0.8058 - val_mean_squared_error: 1.0294
# Epoch 176/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0736 - mean_absolute_error: 0.8240 - mean_squared_error: 1.0736 - val_loss: 0.9889 - val_mean_absolute_error: 0.7825 - val_mean_squared_error: 0.9889
# Epoch 177/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0989 - mean_absolute_error: 0.8275 - mean_squared_error: 1.0989 - val_loss: 1.1564 - val_mean_absolute_error: 0.8741 - val_mean_squared_error: 1.1564
# Epoch 178/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0841 - mean_absolute_error: 0.8191 - mean_squared_error: 1.0841 - val_loss: 1.2107 - val_mean_absolute_error: 0.9003 - val_mean_squared_error: 1.2107
# Epoch 179/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0593 - mean_absolute_error: 0.8122 - mean_squared_error: 1.0593 - val_loss: 1.3091 - val_mean_absolute_error: 0.9474 - val_mean_squared_error: 1.3091
# Epoch 180/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0567 - mean_absolute_error: 0.8099 - mean_squared_error: 1.0567 - val_loss: 1.0571 - val_mean_absolute_error: 0.8266 - val_mean_squared_error: 1.0571
# Epoch 181/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0814 - mean_absolute_error: 0.8159 - mean_squared_error: 1.0814 - val_loss: 1.2736 - val_mean_absolute_error: 0.9271 - val_mean_squared_error: 1.2736
# Epoch 182/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0893 - mean_absolute_error: 0.8133 - mean_squared_error: 1.0893 - val_loss: 1.1652 - val_mean_absolute_error: 0.8813 - val_mean_squared_error: 1.1652
# Epoch 183/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0617 - mean_absolute_error: 0.8182 - mean_squared_error: 1.0617 - val_loss: 1.1607 - val_mean_absolute_error: 0.8784 - val_mean_squared_error: 1.1607
# Epoch 184/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.1074 - mean_absolute_error: 0.8217 - mean_squared_error: 1.1074 - val_loss: 1.0694 - val_mean_absolute_error: 0.8342 - val_mean_squared_error: 1.0694
# Epoch 185/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0730 - mean_absolute_error: 0.8121 - mean_squared_error: 1.0730 - val_loss: 1.0454 - val_mean_absolute_error: 0.8163 - val_mean_squared_error: 1.0454
# Epoch 186/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0561 - mean_absolute_error: 0.8105 - mean_squared_error: 1.0561 - val_loss: 1.1153 - val_mean_absolute_error: 0.8605 - val_mean_squared_error: 1.1153
# Epoch 187/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0524 - mean_absolute_error: 0.8087 - mean_squared_error: 1.0524 - val_loss: 1.2553 - val_mean_absolute_error: 0.9216 - val_mean_squared_error: 1.2553
# Epoch 188/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0861 - mean_absolute_error: 0.8218 - mean_squared_error: 1.0861 - val_loss: 1.1214 - val_mean_absolute_error: 0.8563 - val_mean_squared_error: 1.1214
# Epoch 189/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0618 - mean_absolute_error: 0.8122 - mean_squared_error: 1.0618 - val_loss: 1.1175 - val_mean_absolute_error: 0.8548 - val_mean_squared_error: 1.1175
# Epoch 190/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0452 - mean_absolute_error: 0.8109 - mean_squared_error: 1.0452 - val_loss: 1.2175 - val_mean_absolute_error: 0.9059 - val_mean_squared_error: 1.2175
# Epoch 191/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1157 - mean_absolute_error: 0.8313 - mean_squared_error: 1.1157 - val_loss: 1.0598 - val_mean_absolute_error: 0.8221 - val_mean_squared_error: 1.0598
# Epoch 192/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0513 - mean_absolute_error: 0.8097 - mean_squared_error: 1.0513 - val_loss: 1.2725 - val_mean_absolute_error: 0.9381 - val_mean_squared_error: 1.2725
# Epoch 193/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0595 - mean_absolute_error: 0.8078 - mean_squared_error: 1.0595 - val_loss: 1.0218 - val_mean_absolute_error: 0.8049 - val_mean_squared_error: 1.0218
# Epoch 194/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0833 - mean_absolute_error: 0.8245 - mean_squared_error: 1.0833 - val_loss: 1.1833 - val_mean_absolute_error: 0.8903 - val_mean_squared_error: 1.1833
# Epoch 195/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0604 - mean_absolute_error: 0.8138 - mean_squared_error: 1.0604 - val_loss: 1.0331 - val_mean_absolute_error: 0.8168 - val_mean_squared_error: 1.0331
# Epoch 196/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.0982 - mean_absolute_error: 0.8273 - mean_squared_error: 1.0982 - val_loss: 1.1366 - val_mean_absolute_error: 0.8633 - val_mean_squared_error: 1.1366
# Epoch 197/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0234 - mean_absolute_error: 0.8008 - mean_squared_error: 1.0234 - val_loss: 0.9784 - val_mean_absolute_error: 0.7742 - val_mean_squared_error: 0.9784
# Epoch 198/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0749 - mean_absolute_error: 0.8215 - mean_squared_error: 1.0749 - val_loss: 1.1294 - val_mean_absolute_error: 0.8584 - val_mean_squared_error: 1.1294
# Epoch 199/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0638 - mean_absolute_error: 0.8177 - mean_squared_error: 1.0638 - val_loss: 1.1264 - val_mean_absolute_error: 0.8664 - val_mean_squared_error: 1.1264
# Epoch 200/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1050 - mean_absolute_error: 0.8264 - mean_squared_error: 1.1050 - val_loss: 1.1905 - val_mean_absolute_error: 0.8886 - val_mean_squared_error: 1.1905
# Epoch 201/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0757 - mean_absolute_error: 0.8170 - mean_squared_error: 1.0757 - val_loss: 1.1852 - val_mean_absolute_error: 0.8891 - val_mean_squared_error: 1.1852
# Epoch 202/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0474 - mean_absolute_error: 0.8135 - mean_squared_error: 1.0474 - val_loss: 1.0782 - val_mean_absolute_error: 0.8328 - val_mean_squared_error: 1.0782
# Epoch 203/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0601 - mean_absolute_error: 0.8129 - mean_squared_error: 1.0601 - val_loss: 1.0519 - val_mean_absolute_error: 0.8188 - val_mean_squared_error: 1.0519
# Epoch 204/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0541 - mean_absolute_error: 0.8072 - mean_squared_error: 1.0541 - val_loss: 1.0818 - val_mean_absolute_error: 0.8370 - val_mean_squared_error: 1.0818
# Epoch 205/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0674 - mean_absolute_error: 0.8148 - mean_squared_error: 1.0674 - val_loss: 1.2096 - val_mean_absolute_error: 0.9012 - val_mean_squared_error: 1.2096
# Epoch 206/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0842 - mean_absolute_error: 0.8237 - mean_squared_error: 1.0842 - val_loss: 1.4680 - val_mean_absolute_error: 1.0235 - val_mean_squared_error: 1.4680
# Epoch 207/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0804 - mean_absolute_error: 0.8180 - mean_squared_error: 1.0804 - val_loss: 1.1591 - val_mean_absolute_error: 0.8760 - val_mean_squared_error: 1.1591
# Epoch 208/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0737 - mean_absolute_error: 0.8155 - mean_squared_error: 1.0737 - val_loss: 1.1305 - val_mean_absolute_error: 0.8575 - val_mean_squared_error: 1.1305
# Epoch 209/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0581 - mean_absolute_error: 0.8164 - mean_squared_error: 1.0581 - val_loss: 1.0540 - val_mean_absolute_error: 0.8227 - val_mean_squared_error: 1.0540
# Epoch 210/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0576 - mean_absolute_error: 0.8144 - mean_squared_error: 1.0576 - val_loss: 1.0219 - val_mean_absolute_error: 0.7966 - val_mean_squared_error: 1.0219
# Epoch 211/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1006 - mean_absolute_error: 0.8265 - mean_squared_error: 1.1006 - val_loss: 0.9984 - val_mean_absolute_error: 0.7839 - val_mean_squared_error: 0.9984
# Epoch 212/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0827 - mean_absolute_error: 0.8199 - mean_squared_error: 1.0827 - val_loss: 1.1020 - val_mean_absolute_error: 0.8525 - val_mean_squared_error: 1.1020
# Epoch 213/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0738 - mean_absolute_error: 0.8148 - mean_squared_error: 1.0738 - val_loss: 0.9887 - val_mean_absolute_error: 0.7894 - val_mean_squared_error: 0.9887
# Epoch 214/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0451 - mean_absolute_error: 0.8092 - mean_squared_error: 1.0451 - val_loss: 1.2005 - val_mean_absolute_error: 0.9012 - val_mean_squared_error: 1.2005
# Epoch 215/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0577 - mean_absolute_error: 0.8058 - mean_squared_error: 1.0577 - val_loss: 1.2271 - val_mean_absolute_error: 0.9069 - val_mean_squared_error: 1.2271
# Epoch 216/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0666 - mean_absolute_error: 0.8133 - mean_squared_error: 1.0666 - val_loss: 0.9812 - val_mean_absolute_error: 0.7840 - val_mean_squared_error: 0.9812
# Epoch 217/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0772 - mean_absolute_error: 0.8195 - mean_squared_error: 1.0772 - val_loss: 1.3720 - val_mean_absolute_error: 0.9756 - val_mean_squared_error: 1.3720
# Epoch 218/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0650 - mean_absolute_error: 0.8148 - mean_squared_error: 1.0650 - val_loss: 1.3003 - val_mean_absolute_error: 0.9431 - val_mean_squared_error: 1.3003
# Epoch 219/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0820 - mean_absolute_error: 0.8305 - mean_squared_error: 1.0820 - val_loss: 1.1122 - val_mean_absolute_error: 0.8495 - val_mean_squared_error: 1.1122
# Epoch 220/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0823 - mean_absolute_error: 0.8215 - mean_squared_error: 1.0823 - val_loss: 1.1125 - val_mean_absolute_error: 0.8522 - val_mean_squared_error: 1.1125
# Epoch 221/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0446 - mean_absolute_error: 0.8056 - mean_squared_error: 1.0446 - val_loss: 1.2115 - val_mean_absolute_error: 0.9021 - val_mean_squared_error: 1.2115
# Epoch 222/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0987 - mean_absolute_error: 0.8229 - mean_squared_error: 1.0987 - val_loss: 1.0694 - val_mean_absolute_error: 0.8312 - val_mean_squared_error: 1.0694
# Epoch 223/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0526 - mean_absolute_error: 0.8070 - mean_squared_error: 1.0526 - val_loss: 1.1853 - val_mean_absolute_error: 0.8901 - val_mean_squared_error: 1.1853
# Epoch 224/500
# ...
# Epoch 427/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0716 - mean_absolute_error: 0.8182 - mean_squared_error: 1.0716 - val_loss: 1.2138 - val_mean_absolute_error: 0.9068 - val_mean_squared_error: 1.2138
# Epoch 428/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1109 - mean_absolute_error: 0.8359 - mean_squared_error: 1.1109 - val_loss: 1.1265 - val_mean_absolute_error: 0.8626 - val_mean_squared_error: 1.1265
# Epoch 429/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0677 - mean_absolute_error: 0.8167 - mean_squared_error: 1.0677 - val_loss: 1.1479 - val_mean_absolute_error: 0.8647 - val_mean_squared_error: 1.1479
# Epoch 430/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0830 - mean_absolute_error: 0.8201 - mean_squared_error: 1.0830 - val_loss: 1.2193 - val_mean_absolute_error: 0.9156 - val_mean_squared_error: 1.2193
# Epoch 431/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0967 - mean_absolute_error: 0.8289 - mean_squared_error: 1.0967 - val_loss: 1.2079 - val_mean_absolute_error: 0.9031 - val_mean_squared_error: 1.2079
# Epoch 432/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0503 - mean_absolute_error: 0.8076 - mean_squared_error: 1.0503 - val_loss: 1.0951 - val_mean_absolute_error: 0.8343 - val_mean_squared_error: 1.0951
# Epoch 433/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0457 - mean_absolute_error: 0.8093 - mean_squared_error: 1.0457 - val_loss: 1.1395 - val_mean_absolute_error: 0.8751 - val_mean_squared_error: 1.1395
# Epoch 434/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0695 - mean_absolute_error: 0.8220 - mean_squared_error: 1.0695 - val_loss: 1.1660 - val_mean_absolute_error: 0.8828 - val_mean_squared_error: 1.1660
# Epoch 435/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0762 - mean_absolute_error: 0.8161 - mean_squared_error: 1.0762 - val_loss: 1.1364 - val_mean_absolute_error: 0.8661 - val_mean_squared_error: 1.1364
# Epoch 436/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0802 - mean_absolute_error: 0.8212 - mean_squared_error: 1.0802 - val_loss: 1.5482 - val_mean_absolute_error: 1.0543 - val_mean_squared_error: 1.5482
# Epoch 437/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0328 - mean_absolute_error: 0.8037 - mean_squared_error: 1.0328 - val_loss: 1.0763 - val_mean_absolute_error: 0.8387 - val_mean_squared_error: 1.0763
# Epoch 438/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0810 - mean_absolute_error: 0.8176 - mean_squared_error: 1.0810 - val_loss: 1.2180 - val_mean_absolute_error: 0.9056 - val_mean_squared_error: 1.2180
# Epoch 439/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0739 - mean_absolute_error: 0.8171 - mean_squared_error: 1.0739 - val_loss: 1.0709 - val_mean_absolute_error: 0.8301 - val_mean_squared_error: 1.0709
# Epoch 440/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0653 - mean_absolute_error: 0.8190 - mean_squared_error: 1.0653 - val_loss: 1.0547 - val_mean_absolute_error: 0.8231 - val_mean_squared_error: 1.0547
# Epoch 441/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0830 - mean_absolute_error: 0.8228 - mean_squared_error: 1.0830 - val_loss: 1.3864 - val_mean_absolute_error: 0.9837 - val_mean_squared_error: 1.3864
# Epoch 442/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.1007 - mean_absolute_error: 0.8220 - mean_squared_error: 1.1007 - val_loss: 1.1472 - val_mean_absolute_error: 0.8714 - val_mean_squared_error: 1.1472
# Epoch 443/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0644 - mean_absolute_error: 0.8127 - mean_squared_error: 1.0644 - val_loss: 1.1420 - val_mean_absolute_error: 0.8663 - val_mean_squared_error: 1.1420
# Epoch 444/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0515 - mean_absolute_error: 0.8083 - mean_squared_error: 1.0515 - val_loss: 0.9180 - val_mean_absolute_error: 0.7423 - val_mean_squared_error: 0.9180
# Epoch 445/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0919 - mean_absolute_error: 0.8188 - mean_squared_error: 1.0919 - val_loss: 1.1764 - val_mean_absolute_error: 0.8828 - val_mean_squared_error: 1.1764
# Epoch 446/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0439 - mean_absolute_error: 0.8049 - mean_squared_error: 1.0439 - val_loss: 1.1036 - val_mean_absolute_error: 0.8488 - val_mean_squared_error: 1.1036
# Epoch 447/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0709 - mean_absolute_error: 0.8117 - mean_squared_error: 1.0709 - val_loss: 1.3600 - val_mean_absolute_error: 0.9765 - val_mean_squared_error: 1.3600
# Epoch 448/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1153 - mean_absolute_error: 0.8299 - mean_squared_error: 1.1153 - val_loss: 1.1555 - val_mean_absolute_error: 0.8801 - val_mean_squared_error: 1.1555
# Epoch 449/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0645 - mean_absolute_error: 0.8152 - mean_squared_error: 1.0645 - val_loss: 1.2265 - val_mean_absolute_error: 0.9116 - val_mean_squared_error: 1.2265
# Epoch 450/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0583 - mean_absolute_error: 0.8125 - mean_squared_error: 1.0583 - val_loss: 1.3130 - val_mean_absolute_error: 0.9508 - val_mean_squared_error: 1.3130
# Epoch 451/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0831 - mean_absolute_error: 0.8189 - mean_squared_error: 1.0831 - val_loss: 1.1757 - val_mean_absolute_error: 0.8839 - val_mean_squared_error: 1.1757
# Epoch 452/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0592 - mean_absolute_error: 0.8115 - mean_squared_error: 1.0592 - val_loss: 0.9962 - val_mean_absolute_error: 0.7867 - val_mean_squared_error: 0.9962
# Epoch 453/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0825 - mean_absolute_error: 0.8205 - mean_squared_error: 1.0825 - val_loss: 1.1815 - val_mean_absolute_error: 0.8929 - val_mean_squared_error: 1.1815
# Epoch 454/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0581 - mean_absolute_error: 0.8070 - mean_squared_error: 1.0581 - val_loss: 1.0941 - val_mean_absolute_error: 0.8412 - val_mean_squared_error: 1.0941
# Epoch 455/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0642 - mean_absolute_error: 0.8141 - mean_squared_error: 1.0642 - val_loss: 1.0495 - val_mean_absolute_error: 0.8159 - val_mean_squared_error: 1.0495
# Epoch 456/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0762 - mean_absolute_error: 0.8179 - mean_squared_error: 1.0762 - val_loss: 1.2198 - val_mean_absolute_error: 0.9044 - val_mean_squared_error: 1.2198
# Epoch 457/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0713 - mean_absolute_error: 0.8172 - mean_squared_error: 1.0713 - val_loss: 1.0594 - val_mean_absolute_error: 0.8229 - val_mean_squared_error: 1.0594
# Epoch 458/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0365 - mean_absolute_error: 0.8120 - mean_squared_error: 1.0365 - val_loss: 1.1062 - val_mean_absolute_error: 0.8435 - val_mean_squared_error: 1.1062
# Epoch 459/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0648 - mean_absolute_error: 0.8155 - mean_squared_error: 1.0648 - val_loss: 0.9383 - val_mean_absolute_error: 0.7508 - val_mean_squared_error: 0.9383
# Epoch 460/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0859 - mean_absolute_error: 0.8188 - mean_squared_error: 1.0859 - val_loss: 1.1510 - val_mean_absolute_error: 0.8765 - val_mean_squared_error: 1.1510
# Epoch 461/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0831 - mean_absolute_error: 0.8262 - mean_squared_error: 1.0831 - val_loss: 1.0342 - val_mean_absolute_error: 0.8083 - val_mean_squared_error: 1.0342
# Epoch 462/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0674 - mean_absolute_error: 0.8157 - mean_squared_error: 1.0674 - val_loss: 1.2635 - val_mean_absolute_error: 0.9278 - val_mean_squared_error: 1.2635
# Epoch 463/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1063 - mean_absolute_error: 0.8259 - mean_squared_error: 1.1063 - val_loss: 1.1467 - val_mean_absolute_error: 0.8631 - val_mean_squared_error: 1.1467
# Epoch 464/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0710 - mean_absolute_error: 0.8109 - mean_squared_error: 1.0710 - val_loss: 1.0507 - val_mean_absolute_error: 0.8196 - val_mean_squared_error: 1.0507
# Epoch 465/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.0591 - mean_absolute_error: 0.8141 - mean_squared_error: 1.0591 - val_loss: 1.0353 - val_mean_absolute_error: 0.8137 - val_mean_squared_error: 1.0353
# Epoch 466/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0648 - mean_absolute_error: 0.8206 - mean_squared_error: 1.0648 - val_loss: 1.1776 - val_mean_absolute_error: 0.8887 - val_mean_squared_error: 1.1776
# Epoch 467/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1065 - mean_absolute_error: 0.8253 - mean_squared_error: 1.1065 - val_loss: 1.0883 - val_mean_absolute_error: 0.8449 - val_mean_squared_error: 1.0883
# Epoch 468/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0779 - mean_absolute_error: 0.8195 - mean_squared_error: 1.0779 - val_loss: 1.1151 - val_mean_absolute_error: 0.8608 - val_mean_squared_error: 1.1151
# Epoch 469/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0646 - mean_absolute_error: 0.8117 - mean_squared_error: 1.0646 - val_loss: 1.1599 - val_mean_absolute_error: 0.8772 - val_mean_squared_error: 1.1599
# Epoch 470/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0700 - mean_absolute_error: 0.8116 - mean_squared_error: 1.0700 - val_loss: 1.0582 - val_mean_absolute_error: 0.8203 - val_mean_squared_error: 1.0582
# Epoch 471/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0693 - mean_absolute_error: 0.8211 - mean_squared_error: 1.0693 - val_loss: 1.1280 - val_mean_absolute_error: 0.8570 - val_mean_squared_error: 1.1280
# Epoch 472/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0529 - mean_absolute_error: 0.8112 - mean_squared_error: 1.0529 - val_loss: 1.0203 - val_mean_absolute_error: 0.8022 - val_mean_squared_error: 1.0203
# Epoch 473/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0728 - mean_absolute_error: 0.8157 - mean_squared_error: 1.0728 - val_loss: 1.0460 - val_mean_absolute_error: 0.8152 - val_mean_squared_error: 1.0460
# Epoch 474/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0509 - mean_absolute_error: 0.8099 - mean_squared_error: 1.0509 - val_loss: 1.0027 - val_mean_absolute_error: 0.7819 - val_mean_squared_error: 1.0027
# Epoch 475/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.1004 - mean_absolute_error: 0.8274 - mean_squared_error: 1.1004 - val_loss: 1.4650 - val_mean_absolute_error: 1.0202 - val_mean_squared_error: 1.4650
# Epoch 476/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0908 - mean_absolute_error: 0.8254 - mean_squared_error: 1.0908 - val_loss: 1.5290 - val_mean_absolute_error: 1.0512 - val_mean_squared_error: 1.5290
# Epoch 477/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0549 - mean_absolute_error: 0.8136 - mean_squared_error: 1.0549 - val_loss: 1.2572 - val_mean_absolute_error: 0.9294 - val_mean_squared_error: 1.2572
# Epoch 478/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0493 - mean_absolute_error: 0.8057 - mean_squared_error: 1.0493 - val_loss: 1.1528 - val_mean_absolute_error: 0.8767 - val_mean_squared_error: 1.1528
# Epoch 479/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.1024 - mean_absolute_error: 0.8246 - mean_squared_error: 1.1024 - val_loss: 1.0325 - val_mean_absolute_error: 0.8045 - val_mean_squared_error: 1.0325
# Epoch 480/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.1010 - mean_absolute_error: 0.8227 - mean_squared_error: 1.1010 - val_loss: 1.1148 - val_mean_absolute_error: 0.8519 - val_mean_squared_error: 1.1148
# Epoch 481/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0615 - mean_absolute_error: 0.8143 - mean_squared_error: 1.0615 - val_loss: 0.9905 - val_mean_absolute_error: 0.7824 - val_mean_squared_error: 0.9905
# Epoch 482/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0682 - mean_absolute_error: 0.8193 - mean_squared_error: 1.0682 - val_loss: 1.3480 - val_mean_absolute_error: 0.9630 - val_mean_squared_error: 1.3480
# Epoch 483/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0655 - mean_absolute_error: 0.8146 - mean_squared_error: 1.0655 - val_loss: 1.1765 - val_mean_absolute_error: 0.8802 - val_mean_squared_error: 1.1765
# Epoch 484/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0519 - mean_absolute_error: 0.8079 - mean_squared_error: 1.0519 - val_loss: 0.9421 - val_mean_absolute_error: 0.7636 - val_mean_squared_error: 0.9421
# Epoch 485/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0769 - mean_absolute_error: 0.8200 - mean_squared_error: 1.0769 - val_loss: 1.0896 - val_mean_absolute_error: 0.8448 - val_mean_squared_error: 1.0896
# Epoch 486/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0590 - mean_absolute_error: 0.8088 - mean_squared_error: 1.0590 - val_loss: 1.2020 - val_mean_absolute_error: 0.8953 - val_mean_squared_error: 1.2020
# Epoch 487/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0544 - mean_absolute_error: 0.8111 - mean_squared_error: 1.0544 - val_loss: 1.1758 - val_mean_absolute_error: 0.8838 - val_mean_squared_error: 1.1758
# Epoch 488/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0946 - mean_absolute_error: 0.8244 - mean_squared_error: 1.0946 - val_loss: 1.0909 - val_mean_absolute_error: 0.8355 - val_mean_squared_error: 1.0909
# Epoch 489/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0575 - mean_absolute_error: 0.8107 - mean_squared_error: 1.0575 - val_loss: 1.2958 - val_mean_absolute_error: 0.9465 - val_mean_squared_error: 1.2958
# Epoch 490/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0764 - mean_absolute_error: 0.8228 - mean_squared_error: 1.0764 - val_loss: 1.0600 - val_mean_absolute_error: 0.8281 - val_mean_squared_error: 1.0600
# Epoch 491/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0788 - mean_absolute_error: 0.8171 - mean_squared_error: 1.0788 - val_loss: 1.0925 - val_mean_absolute_error: 0.8361 - val_mean_squared_error: 1.0925
# Epoch 492/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0759 - mean_absolute_error: 0.8225 - mean_squared_error: 1.0759 - val_loss: 1.2484 - val_mean_absolute_error: 0.9261 - val_mean_squared_error: 1.2484
# Epoch 493/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0646 - mean_absolute_error: 0.8135 - mean_squared_error: 1.0646 - val_loss: 1.1180 - val_mean_absolute_error: 0.8541 - val_mean_squared_error: 1.1180
# Epoch 494/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0978 - mean_absolute_error: 0.8273 - mean_squared_error: 1.0978 - val_loss: 1.3703 - val_mean_absolute_error: 0.9771 - val_mean_squared_error: 1.3703
# Epoch 495/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0801 - mean_absolute_error: 0.8174 - mean_squared_error: 1.0801 - val_loss: 1.1438 - val_mean_absolute_error: 0.8719 - val_mean_squared_error: 1.1438
# Epoch 496/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0554 - mean_absolute_error: 0.8113 - mean_squared_error: 1.0554 - val_loss: 1.0641 - val_mean_absolute_error: 0.8240 - val_mean_squared_error: 1.0641
# Epoch 497/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0691 - mean_absolute_error: 0.8177 - mean_squared_error: 1.0691 - val_loss: 1.0838 - val_mean_absolute_error: 0.8379 - val_mean_squared_error: 1.0838
# Epoch 498/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0764 - mean_absolute_error: 0.8153 - mean_squared_error: 1.0764 - val_loss: 1.2678 - val_mean_absolute_error: 0.9328 - val_mean_squared_error: 1.2678
# Epoch 499/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0734 - mean_absolute_error: 0.8201 - mean_squared_error: 1.0734 - val_loss: 1.2542 - val_mean_absolute_error: 0.9209 - val_mean_squared_error: 1.2542
# Epoch 500/500
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0460 - mean_absolute_error: 0.8076 - mean_squared_error: 1.0460 - val_loss: 1.2281 - val_mean_absolute_error: 0.9105 - val_mean_squared_error: 1.2281

# %%
def regression_results(y_true, y_pred):
    # Regression metrics
    ev = explained_variance_score(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred) 
    mse = mean_squared_error(y_true, y_pred) 
    r2 = r2_score(y_true, y_pred)

    print('explained_variance: ', round(ev,4))    
    print('MAE: ', round(mae,4))
    print('MSE: ', round(mse,4))
    print('R²: ', round(r2,4))

# %%
# 7. Evaluamos el modelo

pred_tr = model.predict(X_train)
pred_te = model.predict(X_test)

#%% Model Performance Summary    
print("")
print('---------- Evaluation on Training Data ----------')
regression_results(y_train, pred_tr)
print("")

print('---------- Evaluation on Test Data ----------')
regression_results(y_test, pred_te)
print("")

#%% Results per output
mse_train = mean_squared_error(y_train, pred_tr)

r2_train = r2_score(y_train, pred_tr)

mse_test = mean_squared_error(y_test, pred_te)

r2_test = r2_score(y_test, pred_te)

col_names = ('MSE (train)', 'R2 (train)', 'MSE (test)', 'R2 (test)')

df = np.array([mse_train, r2_train, mse_test, r2_test])

print("")
print('---------- Evaluation per output ----------')
results = pd.DataFrame(data = df.reshape(1,-1), columns = col_names)
print(results)
# Out:
# 123/438 [=======>......................] - ETA: 0s
# 2024-11-13 11:35:53.442933: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 438/438 [==============================] - 1s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
#
# ---------- Evaluation on Training Data ----------
# explained_variance:  0.8962
# MAE:  0.3722
# MSE:  0.3129
# R²:  0.8905
#
# ---------- Evaluation on Test Data ----------
# explained_variance:  0.9002
# MAE:  0.3629
# MSE:  0.3055
# R²:  0.8945
#
#
# ---------- Evaluation per output ----------
#    MSE (train)  R2 (train)  MSE (test)  R2 (test)
# 0      0.31291    0.890485    0.305515   0.894514

# %%
# Prueba de pendiente-intercepto

# %%
import numpy as np
from sklearn.metrics import mean_squared_error

# Carga tus datos reales y predicciones del modelo ANN
# y_true = ... # Valores reales
# y_pred_ann = ... # Predicciones del modelo ANN

# Calcula el Error Cuadrático Medio (MSE)
mse_ann = mean_squared_error(y_true, y_pred_ann)

# Define la tolerancia para el P-I Test
tolerancia = 1.96 * np.sqrt(mse_ann)  # Intervalo de confianza al 95%

# Realiza el P-I Test
p_i_test_ann = np.abs(y_true - y_pred_ann) <= tolerancia

# Calcula la proporción de valores dentro del intervalo
proporcion_ann = np.mean(p_i_test_ann)

print(f"P-I Test Proporción ANN: {proporcion_ann}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       2 from sklearn.metrics import mean_squared_error
#       4 # Carga tus datos reales y predicciones del modelo ANN
#       5 # y_true = ... # Valores reales
#       6 # y_pred_ann = ... # Predicciones del modelo ANN
#       7
#       8 # Calcula el Error Cuadrático Medio (MSE)
# ----> 9 mse_ann = mean_squared_error(y_true, y_pred_ann)
#      11 # Define la tolerancia para el P-I Test
#      12 tolerancia = 1.96 * np.sqrt(mse_ann)  # Intervalo de confianza al 95%
#
# NameError: name 'y_true' is not defined
